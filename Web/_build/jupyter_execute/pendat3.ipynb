# %% [markdown]
# # **Algoritma *K-Means***

# %% [markdown]
# ## **Pengertian *K-Means Clustering***
#
# K-Means Clustering merupakan metode pengelompokan data yang bertujuan memisahkan data ke dalam beberapa kelompok (cluster) berdasarkan kemiripan fitur. Data dengan karakteristik serupa akan ditempatkan dalam satu kelompok, sementara data yang berbeda akan dikelompokkan ke dalam klaster lain. Proses pengelompokan ini menggunakan centroid (titik pusat) sebagai referensi dalam menentukan keanggotaan tiap data pada suatu klaster. Tujuannya adalah untuk memastikan bahwa data yang memiliki kesamaan berada dalam kelompok yang sama, dan data yang berbeda tersebar di kelompok yang berbeda.
#
#
# ## **Manfaat *Clustering***
#
#
# * Clustering berperan penting dalam segmentasi data, yang sangat bermanfaat untuk analisis dan pemecahan berbagai masalah bisnis, seperti segmentasi pelanggan, strategi pemasaran, dan pemetaan wilayah.
#
# * Juga digunakan dalam pengenalan objek di berbagai bidang seperti computer vision dan image processing.
#
# Hasil clustering yang optimal akan menunjukkan tingkat kemiripan yang tinggi antar anggota dalam satu klaster, dan perbedaan yang signifikan antar klaster yang berbeda. Kesamaan yang dimaksud dinilai secara numerik, di mana dua objek dianggap semakin mirip jika nilai ukurannya semakin dekat. Sebaliknya, semakin besar perbedaan nilai, maka semakin rendah tingkat kesamaan. Oleh karena itu, kualitas clustering sangat ditentukan oleh metode yang digunakan.

# %% [markdown]
# ##**Inertia (Sum of Squared Error/SSE)**
#
#
# Dalam algoritma K-Means Clustering, inertia atau SSE (Sum of Squared Error) merupakan salah satu ukuran evaluasi yang digunakan untuk menentukan seberapa baik pengelompokan data ke dalam klaster. Metrik ini menghitung total jumlah kuadrat jarak antara setiap data dengan pusat klaster (centroid) tempat data tersebut tergabung.
#
# Rumus dari inertia adalah:
#
#
# **Inertia
# =
# ∑
# 𝑖
# =
# 1
# 𝑛
# ∥
# 𝑥
# 𝑖
# −
# 𝜇
# 𝑐
# 𝑖
# ∥
# 2
# Inertia=
# i=1
# ∑
# n
# ​
#  ∥x
# i
# ​
#  −μ
# c
# i
# ∥
# 2**
#
#
# **Penjelasan Notasi**
#
# * x
# i
# ​
#  : Titik data ke-
# 𝑖
# i
#
# * 𝜇
# 𝑐
# 𝑖
# μ
# c
# i : Titik pusat (centroid) dari klaster yang berisi
# 𝑥
# 𝑖
# x
# i
# ​
# * ∥
# 𝑥
# 𝑖
# −
# 𝜇
# 𝑐
# 𝑖
# ∥
# 2
# ∥x
# i
# ​
#  −μ
# c
# i 2: Jarak kuadrat antara data
# 𝑥
# 𝑖
# x
# i
# ​
#   dan centroid-nya menggunakan jarak Euclidean
#
# * 𝑛
# n: Total jumlah dat

# %% [markdown]
# ## **Silhouette Analysis**
#
# Silhouette Analysis adalah metode evaluasi yang sering dianggap lebih informatif dibandingkan inertia dalam menilai kualitas hasil clustering, terutama pada algoritma seperti K-Means. Ini karena metrik ini memperhitungkan dua aspek penting sekaligus:
#
# * Kepadatan internal dalam klaster (cohesion)
#
# * Jarak antar klaster yang berbeda (separation)
#
# Silhouette Analysis menilai sejauh mana sebuah titik data cocok berada dalam klaster tempatnya berada dibandingkan dengan klaster terdekat lainnya. Rumus yang digunakan adalah:
#
#
# $$
# s(i) = \frac{b(i) - a(i)}{\max(a(i), b(i))}
# $$
#
#
# **Penjelasan Notasi**:
# * 𝑎
# (
# 𝑖
# )
# a(i): Rata-rata jarak dari titik
# 𝑖
# i ke seluruh titik lain dalam klaster yang sama (ukuran kohesi).
#
# * 𝑏
# (
# 𝑖
# )
# b(i): Rata-rata jarak dari titik
# 𝑖
# i ke semua titik dalam klaster terdekat yang bukan klasternya (ukuran pemisahan).
#
# * 𝑠
# (
# 𝑖
# )
# s(i): Nilai silhouette untuk titik
# 𝑖
# i, berkisar antara -1 hingga 1.
#
#
# **Interpretasi Nilai s(i):**
# * 𝑠
# (
# 𝑖
# )
# s(i):
# 𝑠
# (
# 𝑖
# )
# ≈
# 1
# s(i)≈1: Titik sangat sesuai dengan klasternya dan jauh dari klaster lain.
#
# * 𝑠
# (
# 𝑖
# )
# ≈
# 0
# s(i)≈0: Titik berada di batas antara dua klaster.
#
# * 𝑠
# (
# 𝑖
# )
# ≈
# −
# 1
# s(i)≈−1: Titik mungkin dikelompokkan ke klaster yang salah.
#
#
#
# Untuk mengevaluasi seluruh hasil clustering, digunakan rata-rata dari semua $s(i)$:
#
# $$
# S = \frac{1}{n} \sum_{i=1}^{n} s(i)
# $$
#
# - $n$: Jumlah data keseluruhan
# - $S$: Skor rata-rata silhouette dari seluruh titik data

# %% [markdown]
# ## **Implementasi dengan menggunakan data Iris**

# %%
# %pip install pymysql
# %pip install psycopg2
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pymysql in c:\users\raiha\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (1.1.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1 -> 25.1.1
# [notice] To update, run: C:\Users\raiha\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: psycopg2 in c:\users\raiha\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (2.9.10)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1 -> 25.1.1
# [notice] To update, run: C:\Users\raiha\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# ## **Library yang digunakan**

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import adjusted_rand_score
from sklearn.metrics import silhouette_score
import psycopg2
import pymysql
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## **Pengumpulan Data**

# %%
def get_pg_data():
    conn = psycopg2.connect(
        host="pg-29vania-vaniaptr008-f94a.k.aivencloud.com",
        user="avnadmin",
        password="AVNS_jN7GWD4QIOAFWBZiFM2",
        database="defaultdb",
        port=12525
    )
    cursor = conn.cursor()
    cursor.execute("SELECT * FROM iris_postgresql")  # Pastikan tabel ini ada!
    data = cursor.fetchall()
    columns = [desc[0] for desc in cursor.description]
    cursor.close()
    conn.close()
    return pd.DataFrame(data, columns=columns)

def get_mysql_data():
    conn = pymysql.connect(
        host="mysql-25907135-mysqql.h.aivencloud.com",
        user="avnadmin",
        password="AVNS_-_iUzbq84ojauwfvOBS",
        database="defaultdb",
        port=12005
    )
    cursor = conn.cursor()
    cursor.execute("SELECT * FROM iris_mysql")  # Pastikan tabel ini ada!
    data = cursor.fetchall()
    columns = [desc[0] for desc in cursor.description]
    cursor.close()
    conn.close()
    return pd.DataFrame(data, columns=columns)

# Ambil data dari kedua database
df_postgresql = get_pg_data()
df_mysql = get_mysql_data()

# Gabungkan berdasarkan kolom 'id' dan 'Class'
df_merged = pd.merge(df_mysql, df_postgresql, on=["id", "class"], how="inner")

# Cetak semua data hasil gabungan tanpa indeks
print(df_merged.to_string(index=False))
# Out:
#  id           class  petal_length  petal_width  sepal_length  sepal_width
#   1     Iris-setosa          14.0          2.0          51.0         35.0
#   2     Iris-setosa          14.0          2.0          49.0         30.0
#   3     Iris-setosa          13.0          2.0          47.0         32.0
#   4     Iris-setosa          15.0          2.0          46.0         31.0
#   5     Iris-setosa          14.0          2.0           5.0         36.0
#   6     Iris-setosa           1.7          0.4           5.4          3.9
#   7     Iris-setosa           1.4          0.3           4.6          3.4
#   8     Iris-setosa           1.5          0.2           5.0          3.4
#   9     Iris-setosa           1.4          0.2           4.4          2.9
#  10     Iris-setosa           1.5          0.1          94.0          3.1
#  11     Iris-setosa           1.5          0.2           5.4          3.7
#  12     Iris-setosa           1.6          0.2           4.8          3.4
#  13     Iris-setosa           1.4          0.1           4.8          3.0
#  14     Iris-setosa           1.1          0.1           4.3          3.0
#  15     Iris-setosa           1.2          0.2           5.8         40.0
#  16     Iris-setosa           1.5          0.4           5.7          4.4
#  17     Iris-setosa           1.3          0.4           5.4          3.9
#  18     Iris-setosa           1.4          0.3           5.1          3.5
#  19     Iris-setosa           1.7          0.3           5.7          3.8
#  20     Iris-setosa           1.5          0.3          51.0          3.8
#  21     Iris-setosa           1.7          0.2           5.4          3.4
#  22     Iris-setosa           1.5          0.4           5.1          3.7
#  23     Iris-setosa           1.0          0.2           4.6          3.6
#  24     Iris-setosa           1.7          0.5           5.1          3.3
#  25     Iris-setosa           1.9          0.2           4.8         34.0
#  26     Iris-setosa           1.6          0.2           5.0          3.0
#  27     Iris-setosa           1.6          0.4           5.0          3.4
#  28     Iris-setosa           1.5          0.2           5.2          3.5
#  29     Iris-setosa           1.4          0.2           5.2          3.4
#  30     Iris-setosa           1.6          0.2          74.0          3.2
#  31     Iris-setosa           1.6          0.2           4.8          3.1
#  32     Iris-setosa           1.5          0.4           5.4          3.4
#  33     Iris-setosa           1.5          0.1           5.2          4.1
#  34     Iris-setosa           1.4          0.2           5.5          4.2
#  35     Iris-setosa           1.5          0.1           4.9         94.0
#  36     Iris-setosa           1.2          0.2           5.0          3.2
#  37     Iris-setosa           1.3          0.2           5.5          3.5
#  38     Iris-setosa           1.5          0.1           4.9          3.1
#  39     Iris-setosa           1.3          0.2           4.4          3.0
#  40     Iris-setosa           1.5          0.2           5.1          3.4
#  41     Iris-setosa           1.3          0.3           5.0          3.5
#  42     Iris-setosa           1.3          0.3           4.5          2.3
#  43     Iris-setosa           1.3          0.2           4.4          3.2
#  44     Iris-setosa           1.6          0.6           5.0          3.5
#  45     Iris-setosa           1.9          0.4           5.1          3.8
#  46     Iris-setosa           1.4          0.3           4.8          3.0
#  47     Iris-setosa           1.6          0.2           5.1          3.8
#  48     Iris-setosa           1.4          0.2           4.6          3.2
#  49     Iris-setosa           1.5          0.2           5.3          3.7
#  50     Iris-setosa           1.4          0.2           5.0          3.3
#  51 Iris-versicolor          47.0         14.0          70.0         32.0
#  52 Iris-versicolor          45.0         15.0          64.0         32.0
#  53 Iris-versicolor          49.0         15.0          69.0         31.0
#  54 Iris-versicolor          40.0         13.0          55.0         23.0
#  55 Iris-versicolor          46.0         15.0          65.0         28.0
#  56 Iris-versicolor           4.5          1.3           5.7          2.8
#  57 Iris-versicolor           4.7          1.6           6.3          3.3
#  58 Iris-versicolor           3.3          1.0           4.9          2.4
#  59 Iris-versicolor           4.6          1.3           6.6          2.9
#  60 Iris-versicolor           3.9          1.4           5.2          2.7
# 114  Iris-virginica           5.0          2.0           5.7          2.5
# 115  Iris-virginica           5.1         42.0           5.8          2.8
# 116  Iris-virginica           5.3          2.3           6.4          3.2
# 117  Iris-virginica           5.5          1.8           6.5          3.0
# 118  Iris-virginica           6.7          2.2           7.7          3.8
# 119  Iris-virginica           6.9          2.3           7.7          2.6
# 120  Iris-virginica          50.0          1.5           6.0          2.2
# 121  Iris-virginica           5.7          2.3           6.9          3.2
# 122  Iris-virginica           4.9          2.0           5.6          2.8
# 123  Iris-virginica           6.7          2.0           7.7          2.8
# 124  Iris-virginica           4.9          1.8           6.3          2.7
# 125  Iris-virginica           5.7          2.1           6.7          3.3
# 126  Iris-virginica           6.0         18.0           7.2          3.2
# 127  Iris-virginica           4.8          1.8           6.2          2.8
# 128  Iris-virginica           4.9          1.8           6.1          3.0
# 129  Iris-virginica           5.6          2.1           6.4          2.8
# 130  Iris-virginica          58.0          1.6           7.2          3.0
# 131  Iris-virginica           6.1          1.9           7.4          2.8
# 132  Iris-virginica           6.4          2.0           7.9          3.8
# 133  Iris-virginica           5.6          2.2           6.4          2.8
# 134  Iris-virginica           5.1          1.5           6.3          2.8
# 135  Iris-virginica           5.6         41.0           6.1          2.6
# 136  Iris-virginica           6.1          2.3           7.7          3.0
# 137  Iris-virginica           5.6          2.4           6.3          3.4
# 138  Iris-virginica           5.5          1.8           6.4          3.1
# 139  Iris-virginica           4.8          1.8           6.0          3.0
# 140  Iris-virginica          45.0          2.1           6.9          3.1
# 141  Iris-virginica           5.6          2.4           6.7          3.1
# 142  Iris-virginica           5.1          2.3           6.9          3.1
# 143  Iris-virginica           5.1          1.9           5.8          2.7
# 144  Iris-virginica           5.9          2.3           6.8          3.2
# 145  Iris-virginica           5.7         25.0           6.7          3.3
# 146  Iris-virginica           5.2          2.3           6.7          3.0
# 147  Iris-virginica           5.0          1.9           6.3          2.5
# 148  Iris-virginica           5.2          2.0           6.5          3.0
# 149  Iris-virginica           5.4          2.3           6.2          3.4
# 150  Iris-virginica           5.1          1.8           5.9          3.0

# %% [markdown]
# ## **Clustering pada data Iris menggunakan K-Means dengan jumlah cluster 2,3 dan 4**

# %%
# 1. Siapkan fitur (X) dan label (y)
feature_names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
X = df_merged[feature_names].values
y = df_merged['class'].astype('category').cat.codes.values  # label dikodekan ke angka

# 2. Standarisasi
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 3. Fungsi clustering
def perform_kmeans(X_scaled, y, k):
    kmeans = KMeans(n_clusters=k, random_state=42)
    labels = kmeans.fit_predict(X_scaled)
    centroids = kmeans.cluster_centers_
    accuracy = adjusted_rand_score(y, labels)

    print(f"\nHasil K-Means dengan {k} Klaster:")
    print(f"Centroids:\n{centroids}")
    print(f"Akurasi (Adjusted Rand Score): {accuracy:.3f}")

    return labels, centroids, accuracy

# 4. Jalankan clustering
for k in [2, 3, 4]:
    perform_kmeans(X_scaled, y, k)

print(X_scaled)
# Out:
# Hasil K-Means dengan 2 Klaster:
# Centroids:
# [[-0.20363851 -0.14015855 -0.22594879 -0.15842908]
#  [ 2.85093916  1.96221965  3.16328299  2.21800714]]
# Akurasi (Adjusted Rand Score): 0.003
#
# Hasil K-Means dengan 3 Klaster:
# Centroids:
# [[-0.34755702 -0.33079677 -0.23971791 -0.23892785]
#  [ 2.3185641   1.57512571  2.60161181  2.82089167]
#  [ 1.48336107  2.10088017 -0.07046978 -0.31880571]]
# Akurasi (Adjusted Rand Score): 0.015
#
# Hasil K-Means dengan 4 Klaster:
# Centroids:
# [[-0.34791656 -0.33097495 -0.24018422 -0.26723297]
#  [-0.302254   -0.32567889 -0.18832865 -0.10740464]
#  [-0.29130541 -0.32567889 -0.22515955 -0.12260341]
#  [-0.35152265 -0.36034402 -0.22515955 -0.18339849]
#  [-0.29677971 -0.31701261 -0.16623012 -0.12260341]
#  [-0.302254   -0.30834633 -0.18096247  3.32751733]
#  [-0.302254   -0.33434517 -0.21779337 -0.12260341]
#  [-0.32415118 -0.37767659 -0.23252573 -0.18339849]
#  [-0.31320259 -0.33434517 -0.21779337 -0.16819972]
#  [-0.32962547 -0.29968004 -0.20306101 -0.12260341]
#  [-0.34604835 -0.33434517 -0.22515955 -0.19859726]]

# %%
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## **Model Plotting dengan Jumlah Cluster 2, 3 dan 4**

# %%
# 1. Siapkan fitur (X) dan label (y)
feature_names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
X = df_merged[feature_names].values
y = df_merged['class'].astype('category').cat.codes.values  # label dikodekan ke angka

# 2. Standarisasi data
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# 3. Fungsi untuk melakukan K-Means, plotting dan menampilkan centroid
def perform_kmeans_plot(X_scaled, k):
    kmeans = KMeans(n_clusters=k, random_state=42)
    labels = kmeans.fit_predict(X_scaled)

    # Centroid dari masing-masing klaster
    centroids = kmeans.cluster_centers_

    # Plotting data dan centroid
    plt.figure(figsize=(8, 6))

    # Scatter plot untuk 2 fitur pertama (sepal length & sepal width)
    plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=labels, cmap='Set1', marker='o', edgecolors='k', s=100)

    # Plot centroid dengan warna berbeda
    plt.scatter(centroids[:, 0], centroids[:, 1], c='black', marker='X', s=200, label='Centroids')

    plt.title(f"K-Means Clustering with {k} Clusters")
    plt.xlabel(feature_names[0])
    plt.ylabel(feature_names[1])
    plt.legend()
    plt.show()

# 4. Melakukan clustering dengan K=2, K=3, dan K=4 dan plot hasilnya
for k in [2, 3, 4]:
    perform_kmeans_plot(X_scaled, k)

# %%
#Menggunakan 3 DIMENSI

from mpl_toolkits.mplot3d import Axes3D  # Untuk plotting 3D

def perform_kmeans_plot_3d(X_scaled, k):
    kmeans = KMeans(n_clusters=k, random_state=42)
    labels = kmeans.fit_predict(X_scaled)
    centroids = kmeans.cluster_centers_

    fig = plt.figure(figsize=(10, 8))
    ax = fig.add_subplot(111, projection='3d')

    # Gunakan 3 fitur pertama: sepal_length, sepal_width, petal_length
    ax.scatter(X_scaled[:, 0], X_scaled[:, 1], X_scaled[:, 2],
               c=labels, cmap='Set1', marker='o', edgecolors='k', s=60, alpha=0.8)

    # Plot centroids
    ax.scatter(centroids[:, 0], centroids[:, 1], centroids[:, 2],
               c='black', marker='X', s=200, label='Centroids')

    ax.set_title(f"K-Means Clustering with {k} Clusters (3D)")
    ax.set_xlabel(feature_names[0])
    ax.set_ylabel(feature_names[1])
    ax.set_zlabel(feature_names[2])
    ax.legend()
    plt.show()

for k in [2, 3, 4]:
    perform_kmeans_plot_3d(X_scaled, k)

# %%
print(X_scaled)
# Out:
# [[0.5206243  0.35869565 0.22033898 0.04534606]
#  [0.49832776 0.30434783 0.22033898 0.04534606]
#  [0.47603122 0.32608696 0.20338983 0.04534606]
#  [0.46488294 0.31521739 0.23728814 0.04534606]
#  [0.00780379 0.36956522 0.22033898 0.04534606]
#  [0.0122631  0.02065217 0.01186441 0.0071599 ]
#  [0.00334448 0.01521739 0.00677966 0.00477327]
#  [0.00780379 0.01521739 0.00847458 0.00238663]
#  [0.00111483 0.00978261 0.00677966 0.00238663]
#  [1.         0.01195652 0.00847458 0.        ]
#  [0.0122631  0.01847826 0.00847458 0.00238663]
#  [0.00557414 0.01521739 0.01016949 0.00238663]
#  [0.00557414 0.01086957 0.00677966 0.        ]
#  [0.         0.01086957 0.00169492 0.        ]
#  [0.01672241 0.41304348 0.00338983 0.00238663]
#  [0.03232999 0.01304348 0.08474576 0.42720764]
#  [0.02118172 0.00869565 0.06440678 0.04057279]
#  [0.02006689 0.01086957 0.06610169 0.04057279]
#  [0.02341137 0.00869565 0.0779661  0.0477327 ]
#  [0.03232999 0.01086957 0.96610169 0.03579952]
#  [0.03455964 0.00869565 0.08644068 0.04295943]
#  [0.04013378 0.01956522 0.09152542 0.04534606]
#  [0.02341137 0.00869565 0.0779661  0.05011933]
#  [0.02229654 0.00869565 0.06949153 0.03341289]
#  [0.02006689 0.00652174 0.0779661  0.97613365]
#  [0.03790412 0.01086957 0.08644068 0.05250597]
#  [0.02229654 0.01521739 0.0779661  0.0548926 ]
#  [0.02341137 0.01195652 0.07627119 0.04057279]
#  [0.01895206 0.01086957 0.06440678 0.04057279]
#  [0.02898551 0.01195652 0.74576271 0.0477327 ]
#  [0.02675585 0.01195652 0.0779661  0.0548926 ]
#  [0.02898551 0.01195652 0.06949153 0.05250597]
#  [0.01672241 0.0076087  0.06949153 0.04295943]
#  [0.02787068 0.01304348 0.08305085 0.05250597]
#  [0.02675585 0.01413043 0.07966102 0.59427208]
#  [0.02675585 0.01086957 0.07118644 0.05250597]
#  [0.02229654 0.00543478 0.06779661 0.04295943]
#  [0.0245262  0.01086957 0.07118644 0.04534606]
#  [0.02118172 0.01521739 0.07457627 0.05250597]
#  [0.01783724 0.01086957 0.06949153 0.04057279]]

# %% [markdown]
# ## **Menghitung Inertia untuk Jumlah Cluster 2,3 dan 4**

# %%
# 1. Siapkan fitur (X) dan label (y)
feature_names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
X = df_merged[feature_names].values
y = df_merged['class'].astype('category').cat.codes.values  # label dikodekan ke angka

# 2. Standarisasi data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 3. Fungsi untuk menghitung inertia secara manual
def calculate_inertia_step_by_step(X_scaled, labels, centroids):
    inertia = 0
    print("Langkah-langkah perhitungan Inertia:")

    for i in range(len(X_scaled)):
        cluster = labels[i]
        distance = np.linalg.norm(X_scaled[i] - centroids[cluster]) ** 2
        inertia += distance
        print(f"Titik data {i+1} (Fitur: {X_scaled[i]}), Klaster: {cluster}, "
              f"Centroid: {centroids[cluster]}, Jarak kuadrat: {distance:.3f}, "
              f"Inertia sementara: {inertia:.3f}")

    return inertia

# 4. Fungsi untuk menjalankan KMeans dan menghitung inertia manual
def perform_kmeans(X_scaled, y, k):
    kmeans = KMeans(n_clusters=k, random_state=42)
    labels = kmeans.fit_predict(X_scaled)
    centroids = kmeans.cluster_centers_

    print(f"\n=== Hasil K-Means dengan {k} Klaster ===")
    print(f"Centroids (fitur hasil standarisasi):\n{centroids}")

    # Hitung inertia manual
    manual_inertia = calculate_inertia_step_by_step(X_scaled, labels, centroids)
    print(f"\nTotal Inertia Manual: {manual_inertia:.3f}")

    # Bandingkan dengan inertia dari sklearn
    sklearn_inertia = kmeans.inertia_
    print(f"Inertia dari sklearn: {sklearn_inertia:.3f}")
    print("="*50)

    return labels, centroids, manual_inertia

# 5. Jalankan untuk k=2, 3, dan 4
for k in [2, 3, 4]:
    perform_kmeans(X_scaled, y, k)
# Out:
# === Hasil K-Means dengan 2 Klaster ===
# Centroids (fitur hasil standarisasi):
# [[-0.20363851 -0.14015855 -0.22594879 -0.15842908]
#  [ 2.85093916  1.96221965  3.16328299  2.21800714]]
# Langkah-langkah perhitungan Inertia:
# Titik data 1 (Fitur: [ 2.1228581   2.43886518  0.43043042 -0.16819972]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 12.495, Inertia sementara: 12.495
# Titik data 2 (Fitur: [ 2.01337223  2.00555106  0.43043042 -0.16819972]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 9.950, Inertia sementara: 22.445
# Titik data 3 (Fitur: [ 1.90388635  2.17887671  0.35676862 -0.16819972]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 10.159, Inertia sementara: 32.604
# Titik data 4 (Fitur: [ 1.84914342  2.09221389  0.50409221 -0.16819972]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 9.730, Inertia sementara: 42.335
# Titik data 5 (Fitur: [-0.39531699  2.52552801  0.43043042 -0.16819972]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 7.574, Inertia sementara: 49.908
# Titik data 6 (Fitur: [-0.37341982 -0.25634863 -0.47560965 -0.41138004]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.169, Inertia sementara: 50.077
# Titik data 7 (Fitur: [-0.41721417 -0.29968004 -0.49770819 -0.4265788 ]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.217, Inertia sementara: 50.294
# Titik data 8 (Fitur: [-0.39531699 -0.29968004 -0.49034201 -0.44177757]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.212, Inertia sementara: 50.506
# Titik data 9 (Fitur: [-0.42816276 -0.34301146 -0.49770819 -0.44177757]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.246, Inertia sementara: 50.752
# Titik data 10 (Fitur: [ 4.47680439 -0.32567889 -0.49034201 -0.45697634]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 22.100, Inertia sementara: 72.852
# Titik data 11 (Fitur: [-0.37341982 -0.2736812  -0.49034201 -0.44177757]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.197, Inertia sementara: 73.049
# Titik data 12 (Fitur: [-0.40626558 -0.29968004 -0.48297583 -0.44177757]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.213, Inertia sementara: 73.261
# Titik data 13 (Fitur: [-0.40626558 -0.33434517 -0.49770819 -0.45697634]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.242, Inertia sementara: 73.503
# Titik data 14 (Fitur: [-0.43363705 -0.33434517 -0.51980673 -0.45697634]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.266, Inertia sementara: 73.769
# Titik data 15 (Fitur: [-0.35152265  2.8721793  -0.51244055 -0.44177757]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 9.258, Inertia sementara: 83.028
# Titik data 16 (Fitur: [-0.35699694 -0.21301722 -0.49034201 -0.41138004]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.163, Inertia sementara: 83.190
# Titik data 17 (Fitur: [-0.37341982 -0.25634863 -0.50507437 -0.41138004]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.184, Inertia sementara: 83.375
# Titik data 18 (Fitur: [-0.3898427  -0.29101376 -0.49770819 -0.4265788 ]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.203, Inertia sementara: 83.578
# Titik data 19 (Fitur: [-0.35699694 -0.26501491 -0.47560965 -0.4265788 ]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.173, Inertia sementara: 83.751
# Titik data 20 (Fitur: [ 2.1228581  -0.26501491 -0.49034201 -0.4265788 ]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 5.570, Inertia sementara: 89.321
# Titik data 21 (Fitur: [-0.37341982 -0.29968004 -0.47560965 -0.44177757]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.197, Inertia sementara: 89.518
# Titik data 22 (Fitur: [-0.3898427  -0.2736812  -0.49034201 -0.41138004]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.186, Inertia sementara: 89.704
# Titik data 23 (Fitur: [-0.41721417 -0.28234748 -0.52717291 -0.44177757]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.237, Inertia sementara: 89.941
# Titik data 24 (Fitur: [-0.3898427  -0.30834633 -0.47560965 -0.39618127]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.182, Inertia sementara: 90.123
# Titik data 25 (Fitur: [-0.40626558  2.35220236 -0.46087729 -0.44177757]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 6.388, Inertia sementara: 96.512
# Titik data 26 (Fitur: [-0.39531699 -0.33434517 -0.48297583 -0.44177757]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.221, Inertia sementara: 96.732
# Titik data 27 (Fitur: [-0.39531699 -0.29968004 -0.48297583 -0.41138004]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.192, Inertia sementara: 96.925
# Titik data 28 (Fitur: [-0.38436841 -0.29101376 -0.49034201 -0.44177757]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.206, Inertia sementara: 97.130
# Titik data 29 (Fitur: [-0.38436841 -0.29968004 -0.49770819 -0.44177757]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.212, Inertia sementara: 97.342
# Titik data 30 (Fitur: [ 3.38194565 -0.31701261 -0.48297583 -0.44177757]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 13.034, Inertia sementara: 110.376
# Titik data 31 (Fitur: [-0.40626558 -0.32567889 -0.48297583 -0.44177757]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.222, Inertia sementara: 110.598
# Titik data 32 (Fitur: [-0.37341982 -0.29968004 -0.49034201 -0.41138004]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.188, Inertia sementara: 110.786
# Titik data 33 (Fitur: [-0.38436841 -0.23901607 -0.49034201 -0.45697634]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.201, Inertia sementara: 110.988
# Titik data 34 (Fitur: [-0.36794553 -0.23034979 -0.49770819 -0.44177757]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.189, Inertia sementara: 111.177
# Titik data 35 (Fitur: [-0.40079129  7.55197178 -0.49034201 -0.45697634]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 59.367, Inertia sementara: 170.544
# Titik data 36 (Fitur: [-0.39531699 -0.31701261 -0.51244055 -0.44177757]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.230, Inertia sementara: 170.774
# Titik data 37 (Fitur: [-0.36794553 -0.29101376 -0.50507437 -0.44177757]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.208, Inertia sementara: 170.982
# Titik data 38 (Fitur: [-0.40079129 -0.32567889 -0.49034201 -0.45697634]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.232, Inertia sementara: 171.215
# Titik data 39 (Fitur: [-0.42816276 -0.33434517 -0.50507437 -0.44177757]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.246, Inertia sementara: 171.461
# Titik data 40 (Fitur: [-0.3898427  -0.29968004 -0.49034201 -0.44177757]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.210, Inertia sementara: 171.671
# Titik data 41 (Fitur: [-0.39531699 -0.29101376 -0.50507437 -0.4265788 ]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.209, Inertia sementara: 171.881
# Titik data 42 (Fitur: [-0.42268846 -0.39500915 -0.50507437 -0.4265788 ]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.263, Inertia sementara: 172.143
# Titik data 43 (Fitur: [-0.42816276 -0.31701261 -0.50507437 -0.44177757]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.240, Inertia sementara: 172.383
# Titik data 44 (Fitur: [-0.39531699 -0.29101376 -0.48297583 -0.3809825 ]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.175, Inertia sementara: 172.558
# Titik data 45 (Fitur: [-0.3898427  -0.26501491 -0.46087729 -0.41138004]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.169, Inertia sementara: 172.728
# Titik data 46 (Fitur: [-0.40626558 -0.33434517 -0.49770819 -0.4265788 ]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.225, Inertia sementara: 172.952
# Titik data 47 (Fitur: [-0.3898427  -0.26501491 -0.48297583 -0.44177757]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.197, Inertia sementara: 173.149
# Titik data 48 (Fitur: [-0.41721417 -0.31701261 -0.49770819 -0.44177757]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.231, Inertia sementara: 173.380
# Titik data 49 (Fitur: [-0.37889411 -0.2736812  -0.49034201 -0.44177757]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.199, Inertia sementara: 173.579
# Titik data 50 (Fitur: [-0.39531699 -0.30834633 -0.49770819 -0.44177757]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.219, Inertia sementara: 173.798
# Titik data 51 (Fitur: [3.1629739  2.17887671 2.86126963 1.65565265]), Klaster: 1, Centroid: [2.85093916 1.96221965 3.16328299 2.21800714], Jarak kuadrat: 0.552, Inertia sementara: 174.350
# Titik data 52 (Fitur: [2.83451628 2.17887671 2.71394605 1.80764035]), Klaster: 1, Centroid: [2.85093916 1.96221965 3.16328299 2.21800714], Jarak kuadrat: 0.418, Inertia sementara: 174.767
# Titik data 53 (Fitur: [3.10823096 2.09221389 3.00859322 1.80764035]), Klaster: 1, Centroid: [2.85093916 1.96221965 3.16328299 2.21800714], Jarak kuadrat: 0.275, Inertia sementara: 175.043
# Titik data 54 (Fitur: [2.34182985 1.3989113  2.34563707 1.50366496]), Klaster: 1, Centroid: [2.85093916 1.96221965 3.16328299 2.21800714], Jarak kuadrat: 1.755, Inertia sementara: 176.798
# Titik data 55 (Fitur: [2.88925922 1.83222542 2.78760784 1.80764035]), Klaster: 1, Centroid: [2.85093916 1.96221965 3.16328299 2.21800714], Jarak kuadrat: 0.328, Inertia sementara: 177.126
# Titik data 56 (Fitur: [-0.35699694 -0.35167774 -0.26935663 -0.27459111]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.084, Inertia sementara: 177.209
# Titik data 57 (Fitur: [-0.32415118 -0.30834633 -0.25462427 -0.2289948 ]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.049, Inertia sementara: 177.258
# Titik data 58 (Fitur: [-0.40079129 -0.38634287 -0.35775078 -0.32018742]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.143, Inertia sementara: 177.401
# Titik data 59 (Fitur: [-0.3077283  -0.34301146 -0.26199045 -0.27459111]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.067, Inertia sementara: 177.468
# Titik data 60 (Fitur: [-0.38436841 -0.36034402 -0.3135537  -0.25939234]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.099, Inertia sementara: 177.567
# Titik data 61 (Fitur: [-0.39531699 -0.421008   -0.34301842 -0.32018742]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.155, Inertia sementara: 177.722
# Titik data 62 (Fitur: [-0.34604835 -0.33434517 -0.29145517 -0.24419357]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.070, Inertia sementara: 177.792
# Titik data 63 (Fitur: [-0.34057406 -0.40367543 -0.30618753 -0.32018742]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.121, Inertia sementara: 177.913
# Titik data 64 (Fitur: [-0.33509976 -0.34301146 -0.25462427 -0.25939234]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.069, Inertia sementara: 177.982
# Titik data 65 (Fitur: [-0.36247123 -0.34301146 -0.33565224 -0.27459111]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.092, Inertia sementara: 178.074
# Titik data 66 (Fitur: [-0.302254   -0.32567889 -0.27672281 -0.25939234]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.057, Inertia sementara: 178.131
# Titik data 67 (Fitur: [-0.36247123 -0.33434517 -0.26935663 -0.24419357]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.072, Inertia sementara: 178.203
# Titik data 68 (Fitur: [-0.35152265 -0.36034402 -0.29882135 -0.32018742]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.102, Inertia sementara: 178.305
# Titik data 69 (Fitur: [-0.32962547 -0.40367543 -0.26935663 -0.24419357]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.095, Inertia sementara: 178.400
# Titik data 70 (Fitur: [-0.36247123 -0.37767659 -0.3135537  -0.30498865]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.111, Inertia sementara: 178.510
# Titik data 71 (Fitur: [-0.34604835 -0.31701261 -0.24725809 -0.19859726]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.054, Inertia sementara: 178.564
# Titik data 72 (Fitur: [-0.33509976 -0.35167774 -0.30618753 -0.27459111]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.082, Inertia sementara: 178.646
# Titik data 73 (Fitur: [-0.32415118 -0.37767659 -0.23989191 -0.24419357]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.078, Inertia sementara: 178.724
# Titik data 74 (Fitur: [-0.33509976 -0.35167774 -0.25462427 -0.28978988]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.080, Inertia sementara: 178.805
# Titik data 75 (Fitur: [-0.31867688 -0.34301146 -0.28408899 -0.27459111]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.071, Inertia sementara: 178.876
# Titik data 76 (Fitur: [-0.3077283  -0.33434517 -0.27672281 -0.25939234]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.061, Inertia sementara: 178.937
# Titik data 77 (Fitur: [-0.29677971 -0.35167774 -0.24725809 -0.25939234]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.064, Inertia sementara: 179.001
# Titik data 78 (Fitur: [-0.302254   -0.33434517 -0.23252573 -0.21379603]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.051, Inertia sementara: 179.052
# Titik data 79 (Fitur: [-0.34057406 -0.34301146 -0.26935663 -0.24419357]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.069, Inertia sementara: 179.121
# Titik data 80 (Fitur: [-0.35699694 -0.3690103  -0.34301842 -0.32018742]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.116, Inertia sementara: 179.237
# Titik data 81 (Fitur: [-0.36794553 -0.38634287 -0.32091988 -0.30498865]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.118, Inertia sementara: 179.355
# Titik data 82 (Fitur: [-0.36794553 -0.38634287 -0.32828606 -0.32018742]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.124, Inertia sementara: 179.479
# Titik data 83 (Fitur: [-0.35152265 -0.36034402 -0.3135537  -0.28978988]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.095, Inertia sementara: 179.574
# Titik data 84 (Fitur: [-0.34057406 -0.36034402 -0.22515955 -0.2289948 ]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.072, Inertia sementara: 179.646
# Titik data 85 (Fitur: [-0.37341982 -0.33434517 -0.26935663 -0.24419357]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.076, Inertia sementara: 179.722
# Titik data 86 (Fitur: [-0.34057406 -0.29968004 -0.26935663 -0.2289948 ]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.051, Inertia sementara: 179.773
# Titik data 87 (Fitur: [-0.302254   -0.32567889 -0.25462427 -0.24419357]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.052, Inertia sementara: 179.826
# Titik data 88 (Fitur: [-0.32415118 -0.39500915 -0.27672281 -0.27459111]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.096, Inertia sementara: 179.921
# Titik data 89 (Fitur: [-0.36247123 -0.33434517 -0.29882135 -0.27459111]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.082, Inertia sementara: 180.003
# Titik data 90 (Fitur: [-0.36794553 -0.37767659 -0.30618753 -0.27459111]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.103, Inertia sementara: 180.106
# Titik data 91 (Fitur: [-0.36794553 -0.3690103  -0.27672281 -0.28978988]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.099, Inertia sementara: 180.205
# Titik data 92 (Fitur: [-0.33509976 -0.33434517 -0.26199045 -0.25939234]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.066, Inertia sementara: 180.272
# Titik data 93 (Fitur: [-0.35152265 -0.3690103  -0.30618753 -0.28978988]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.098, Inertia sementara: 180.370
# Titik data 94 (Fitur: [-0.39531699 -0.39500915 -0.35775078 -0.32018742]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.145, Inertia sementara: 180.515
# Titik data 95 (Fitur: [-0.36247123 -0.36034402 -0.29145517 -0.27459111]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.091, Inertia sementara: 180.607
# Titik data 96 (Fitur: [-0.35699694 -0.33434517 -0.29145517 -0.28978988]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.083, Inertia sementara: 180.689
# Titik data 97 (Fitur: [-0.35699694 -0.34301146 -0.29145517 -0.27459111]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.082, Inertia sementara: 180.772
# Titik data 98 (Fitur: [-0.32962547 -0.34301146 -0.28408899 -0.27459111]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.074, Inertia sementara: 180.846
# Titik data 99 (Fitur: [-0.3898427  -0.37767659 -0.37984932 -0.30498865]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.136, Inertia sementara: 180.982
# Titik data 100 (Fitur: [-0.35699694 -0.35167774 -0.29882135 -0.27459111]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.087, Inertia sementara: 181.069
# Titik data 101 (Fitur: [2.77977334 2.26553954 3.81887296 3.32751733]), Klaster: 1, Centroid: [2.85093916 1.96221965 3.16328299 2.21800714], Jarak kuadrat: 1.758, Inertia sementara: 182.827
# Titik data 102 (Fitur: [2.50605866 1.74556259 3.15591681 2.41559114]), Klaster: 1, Centroid: [2.85093916 1.96221965 3.16328299 2.21800714], Jarak kuadrat: 0.205, Inertia sementara: 183.032
# Titik data 103 (Fitur: [3.21771684 2.00555106 3.74521117 2.71956654]), Klaster: 1, Centroid: [2.85093916 1.96221965 3.16328299 2.21800714], Jarak kuadrat: 0.727, Inertia sementara: 183.758
# Titik data 104 (Fitur: [2.77977334 1.91888824 3.52422578 2.26360344]), Klaster: 1, Centroid: [2.85093916 1.96221965 3.16328299 2.21800714], Jarak kuadrat: 0.139, Inertia sementara: 183.898
# Titik data 105 (Fitur: [2.88925922 2.00555106 3.67154937 2.87155424]), Klaster: 1, Centroid: [2.85093916 1.96221965 3.16328299 2.21800714], Jarak kuadrat: 0.689, Inertia sementara: 184.587
# Titik data 106 (Fitur: [-0.25298536 -0.33434517 -0.11466686 -0.15300095]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.053, Inertia sementara: 184.639
# Titik data 107 (Fitur: [-0.40079129 -0.37767659 -0.26935663 -0.21379603]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.100, Inertia sementara: 184.739
# Titik data 108 (Fitur: [-0.26940824 -0.34301146 -0.1367654  -0.19859726]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.055, Inertia sementara: 184.794
# Titik data 109 (Fitur: [-0.302254   -0.37767659 -0.1735963  -0.19859726]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.070, Inertia sementara: 184.865
# Titik data 110 (Fitur: [-0.27488253 -0.28234748 -0.15149776 -0.09220587]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.035, Inertia sementara: 184.900
# Titik data 111 (Fitur: [-0.31320259 -0.31701261 -0.22515955 -0.16819972]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.043, Inertia sementara: 184.943
# Titik data 112 (Fitur: [-0.31867688 -0.36034402 -0.21042719 -0.18339849]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.063, Inertia sementara: 185.006
# Titik data 113 (Fitur: [-0.29677971 -0.33434517 -0.19569483 -0.15300095]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.047, Inertia sementara: 185.053
# Titik data 114 (Fitur: [-0.35699694 -0.37767659 -0.23252573 -0.16819972]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.080, Inertia sementara: 185.133
# Titik data 115 (Fitur: [-0.35152265 -0.35167774 -0.22515955  5.91130819]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 36.908, Inertia sementara: 222.042
# Titik data 116 (Fitur: [-0.31867688 -0.31701261 -0.21042719 -0.12260341]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.046, Inertia sementara: 222.088
# Titik data 117 (Fitur: [-0.31320259 -0.33434517 -0.19569483 -0.19859726]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.052, Inertia sementara: 222.140
# Titik data 118 (Fitur: [-0.24751107 -0.26501491 -0.10730068 -0.13780218]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.032, Inertia sementara: 222.172
# Titik data 119 (Fitur: [-0.24751107 -0.3690103  -0.09256832 -0.12260341]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.073, Inertia sementara: 222.245
# Titik data 120 (Fitur: [-0.34057406 -0.40367543  3.08225502 -0.24419357]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 11.040, Inertia sementara: 233.285
# Titik data 121 (Fitur: [-0.29130541 -0.31701261 -0.18096247 -0.12260341]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.042, Inertia sementara: 233.327
# Titik data 122 (Fitur: [-0.36247123 -0.35167774 -0.23989191 -0.16819972]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.070, Inertia sementara: 233.398
# Titik data 123 (Fitur: [-0.24751107 -0.35167774 -0.10730068 -0.16819972]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.061, Inertia sementara: 233.459
# Titik data 124 (Fitur: [-0.32415118 -0.36034402 -0.23989191 -0.19859726]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.065, Inertia sementara: 233.523
# Titik data 125 (Fitur: [-0.302254   -0.30834633 -0.18096247 -0.15300095]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.040, Inertia sementara: 233.563
# Titik data 126 (Fitur: [-0.27488253 -0.31701261 -0.15886394  2.26360344]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 5.907, Inertia sementara: 239.471
# Titik data 127 (Fitur: [-0.32962547 -0.35167774 -0.24725809 -0.19859726]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.063, Inertia sementara: 239.533
# Titik data 128 (Fitur: [-0.33509976 -0.33434517 -0.23989191 -0.19859726]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.057, Inertia sementara: 239.590
# Titik data 129 (Fitur: [-0.31867688 -0.35167774 -0.18832865 -0.15300095]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.059, Inertia sementara: 239.649
# Titik data 130 (Fitur: [-0.27488253 -0.33434517  3.67154937 -0.2289948 ]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 15.238, Inertia sementara: 254.888
# Titik data 131 (Fitur: [-0.26393395 -0.35167774 -0.15149776 -0.18339849]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.055, Inertia sementara: 254.942
# Titik data 132 (Fitur: [-0.23656248 -0.26501491 -0.12939922 -0.16819972]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.026, Inertia sementara: 254.968
# Titik data 133 (Fitur: [-0.31867688 -0.35167774 -0.18832865 -0.13780218]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.060, Inertia sementara: 255.028
# Titik data 134 (Fitur: [-0.32415118 -0.35167774 -0.22515955 -0.24419357]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.067, Inertia sementara: 255.095
# Titik data 135 (Fitur: [-0.33509976 -0.3690103  -0.18832865  5.75932049]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 35.091, Inertia sementara: 290.186
# Titik data 136 (Fitur: [-0.24751107 -0.33434517 -0.15149776 -0.12260341]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.046, Inertia sementara: 290.232
# Titik data 137 (Fitur: [-0.32415118 -0.29968004 -0.18832865 -0.10740464]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.044, Inertia sementara: 290.276
# Titik data 138 (Fitur: [-0.31867688 -0.32567889 -0.19569483 -0.19859726]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.050, Inertia sementara: 290.326
# Titik data 139 (Fitur: [-0.34057406 -0.33434517 -0.24725809 -0.19859726]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.059, Inertia sementara: 290.385
# Titik data 140 (Fitur: [-0.29130541 -0.32567889  2.71394605 -0.15300095]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 8.685, Inertia sementara: 299.070
# Titik data 141 (Fitur: [-0.302254   -0.32567889 -0.18832865 -0.10740464]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.048, Inertia sementara: 299.118
# Titik data 142 (Fitur: [-0.29130541 -0.32567889 -0.22515955 -0.12260341]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.043, Inertia sementara: 299.161
# Titik data 143 (Fitur: [-0.35152265 -0.36034402 -0.22515955 -0.18339849]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.071, Inertia sementara: 299.232
# Titik data 144 (Fitur: [-0.29677971 -0.31701261 -0.16623012 -0.12260341]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.045, Inertia sementara: 299.277
# Titik data 145 (Fitur: [-0.302254   -0.30834633 -0.18096247  3.32751733]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 12.192, Inertia sementara: 311.469
# Titik data 146 (Fitur: [-0.302254   -0.33434517 -0.21779337 -0.12260341]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.049, Inertia sementara: 311.518
# Titik data 147 (Fitur: [-0.32415118 -0.37767659 -0.23252573 -0.18339849]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.072, Inertia sementara: 311.589
# Titik data 148 (Fitur: [-0.31320259 -0.33434517 -0.21779337 -0.16819972]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.050, Inertia sementara: 311.639
# Titik data 149 (Fitur: [-0.32962547 -0.29968004 -0.20306101 -0.12260341]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.043, Inertia sementara: 311.682
# Titik data 150 (Fitur: [-0.34604835 -0.33434517 -0.22515955 -0.19859726]), Klaster: 0, Centroid: [-0.20363851 -0.14015855 -0.22594879 -0.15842908], Jarak kuadrat: 0.060, Inertia sementara: 311.742
#
# Total Inertia Manual: 311.742
# Inertia dari sklearn: 311.742
# ==================================================
#
# === Hasil K-Means dengan 3 Klaster ===
# Centroids (fitur hasil standarisasi):
# [[-0.34755702 -0.33079677 -0.23971791 -0.23892785]
#  [ 2.3185641   1.57512571  2.60161181  2.82089167]
#  [ 1.48336107  2.10088017 -0.07046978 -0.31880571]]
# Langkah-langkah perhitungan Inertia:
# Titik data 1 (Fitur: [ 2.1228581   2.43886518  0.43043042 -0.16819972]), Klaster: 2, Centroid: [ 1.48336107  2.10088017 -0.07046978 -0.31880571], Jarak kuadrat: 0.797, Inertia sementara: 0.797
# Titik data 2 (Fitur: [ 2.01337223  2.00555106  0.43043042 -0.16819972]), Klaster: 2, Centroid: [ 1.48336107  2.10088017 -0.07046978 -0.31880571], Jarak kuadrat: 0.564, Inertia sementara: 1.360
# Titik data 3 (Fitur: [ 1.90388635  2.17887671  0.35676862 -0.16819972]), Klaster: 2, Centroid: [ 1.48336107  2.10088017 -0.07046978 -0.31880571], Jarak kuadrat: 0.388, Inertia sementara: 1.748
# Titik data 4 (Fitur: [ 1.84914342  2.09221389  0.50409221 -0.16819972]), Klaster: 2, Centroid: [ 1.48336107  2.10088017 -0.07046978 -0.31880571], Jarak kuadrat: 0.487, Inertia sementara: 2.235
# Titik data 5 (Fitur: [-0.39531699  2.52552801  0.43043042 -0.16819972]), Klaster: 2, Centroid: [ 1.48336107  2.10088017 -0.07046978 -0.31880571], Jarak kuadrat: 3.983, Inertia sementara: 6.219
# Titik data 6 (Fitur: [-0.37341982 -0.25634863 -0.47560965 -0.41138004]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.092, Inertia sementara: 6.310
# Titik data 7 (Fitur: [-0.41721417 -0.29968004 -0.49770819 -0.4265788 ]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.108, Inertia sementara: 6.418
# Titik data 8 (Fitur: [-0.39531699 -0.29968004 -0.49034201 -0.44177757]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.107, Inertia sementara: 6.525
# Titik data 9 (Fitur: [-0.42816276 -0.34301146 -0.49770819 -0.44177757]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.114, Inertia sementara: 6.639
# Titik data 10 (Fitur: [ 4.47680439 -0.32567889 -0.49034201 -0.45697634]), Klaster: 2, Centroid: [ 1.48336107  2.10088017 -0.07046978 -0.31880571], Jarak kuadrat: 15.044, Inertia sementara: 21.684
# Titik data 11 (Fitur: [-0.37341982 -0.2736812  -0.49034201 -0.44177757]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.108, Inertia sementara: 21.791
# Titik data 12 (Fitur: [-0.40626558 -0.29968004 -0.48297583 -0.44177757]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.105, Inertia sementara: 21.896
# Titik data 13 (Fitur: [-0.40626558 -0.33434517 -0.49770819 -0.45697634]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.118, Inertia sementara: 22.014
# Titik data 14 (Fitur: [-0.43363705 -0.33434517 -0.51980673 -0.45697634]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.133, Inertia sementara: 22.147
# Titik data 15 (Fitur: [-0.35152265  2.8721793  -0.51244055 -0.44177757]), Klaster: 2, Centroid: [ 1.48336107  2.10088017 -0.07046978 -0.31880571], Jarak kuadrat: 4.172, Inertia sementara: 26.319
# Titik data 16 (Fitur: [-0.35699694 -0.21301722 -0.49034201 -0.41138004]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.107, Inertia sementara: 26.426
# Titik data 17 (Fitur: [-0.37341982 -0.25634863 -0.50507437 -0.41138004]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.106, Inertia sementara: 26.532
# Titik data 18 (Fitur: [-0.3898427  -0.29101376 -0.49770819 -0.4265788 ]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.105, Inertia sementara: 26.637
# Titik data 19 (Fitur: [-0.35699694 -0.26501491 -0.47560965 -0.4265788 ]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.095, Inertia sementara: 26.733
# Titik data 20 (Fitur: [ 2.1228581  -0.26501491 -0.49034201 -0.4265788 ]), Klaster: 2, Centroid: [ 1.48336107  2.10088017 -0.07046978 -0.31880571], Jarak kuadrat: 6.194, Inertia sementara: 32.927
# Titik data 21 (Fitur: [-0.37341982 -0.29968004 -0.47560965 -0.44177757]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.098, Inertia sementara: 33.025
# Titik data 22 (Fitur: [-0.3898427  -0.2736812  -0.49034201 -0.41138004]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.098, Inertia sementara: 33.123
# Titik data 23 (Fitur: [-0.41721417 -0.28234748 -0.52717291 -0.44177757]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.131, Inertia sementara: 33.254
# Titik data 24 (Fitur: [-0.3898427  -0.30834633 -0.47560965 -0.39618127]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.083, Inertia sementara: 33.337
# Titik data 25 (Fitur: [-0.40626558  2.35220236 -0.46087729 -0.44177757]), Klaster: 2, Centroid: [ 1.48336107  2.10088017 -0.07046978 -0.31880571], Jarak kuadrat: 3.801, Inertia sementara: 37.138
# Titik data 26 (Fitur: [-0.39531699 -0.33434517 -0.48297583 -0.44177757]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.103, Inertia sementara: 37.241
# Titik data 27 (Fitur: [-0.39531699 -0.29968004 -0.48297583 -0.41138004]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.092, Inertia sementara: 37.333
# Titik data 28 (Fitur: [-0.38436841 -0.29101376 -0.49034201 -0.44177757]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.107, Inertia sementara: 37.440
# Titik data 29 (Fitur: [-0.38436841 -0.29968004 -0.49770819 -0.44177757]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.110, Inertia sementara: 37.550
# Titik data 30 (Fitur: [ 3.38194565 -0.31701261 -0.48297583 -0.44177757]), Klaster: 2, Centroid: [ 1.48336107  2.10088017 -0.07046978 -0.31880571], Jarak kuadrat: 9.636, Inertia sementara: 47.186
# Titik data 31 (Fitur: [-0.40626558 -0.32567889 -0.48297583 -0.44177757]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.104, Inertia sementara: 47.290
# Titik data 32 (Fitur: [-0.37341982 -0.29968004 -0.49034201 -0.41138004]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.094, Inertia sementara: 47.384
# Titik data 33 (Fitur: [-0.38436841 -0.23901607 -0.49034201 -0.45697634]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.120, Inertia sementara: 47.504
# Titik data 34 (Fitur: [-0.36794553 -0.23034979 -0.49770819 -0.44177757]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.118, Inertia sementara: 47.622
# Titik data 35 (Fitur: [-0.40079129  7.55197178 -0.49034201 -0.45697634]), Klaster: 2, Centroid: [ 1.48336107  2.10088017 -0.07046978 -0.31880571], Jarak kuadrat: 33.460, Inertia sementara: 81.082
# Titik data 36 (Fitur: [-0.39531699 -0.31701261 -0.51244055 -0.44177757]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.118, Inertia sementara: 81.200
# Titik data 37 (Fitur: [-0.36794553 -0.29101376 -0.50507437 -0.44177757]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.114, Inertia sementara: 81.314
# Titik data 38 (Fitur: [-0.40079129 -0.32567889 -0.49034201 -0.45697634]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.113, Inertia sementara: 81.427
# Titik data 39 (Fitur: [-0.42816276 -0.33434517 -0.50507437 -0.44177757]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.118, Inertia sementara: 81.545
# Titik data 40 (Fitur: [-0.3898427  -0.29968004 -0.49034201 -0.44177757]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.107, Inertia sementara: 81.652
# Titik data 41 (Fitur: [-0.39531699 -0.29101376 -0.50507437 -0.4265788 ]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.109, Inertia sementara: 81.761
# Titik data 42 (Fitur: [-0.42268846 -0.39500915 -0.50507437 -0.4265788 ]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.115, Inertia sementara: 81.876
# Titik data 43 (Fitur: [-0.42816276 -0.31701261 -0.50507437 -0.44177757]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.118, Inertia sementara: 81.995
# Titik data 44 (Fitur: [-0.39531699 -0.29101376 -0.48297583 -0.3809825 ]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.083, Inertia sementara: 82.078
# Titik data 45 (Fitur: [-0.3898427  -0.26501491 -0.46087729 -0.41138004]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.085, Inertia sementara: 82.163
# Titik data 46 (Fitur: [-0.40626558 -0.33434517 -0.49770819 -0.4265788 ]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.105, Inertia sementara: 82.268
# Titik data 47 (Fitur: [-0.3898427  -0.26501491 -0.48297583 -0.44177757]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.106, Inertia sementara: 82.374
# Titik data 48 (Fitur: [-0.41721417 -0.31701261 -0.49770819 -0.44177757]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.113, Inertia sementara: 82.487
# Titik data 49 (Fitur: [-0.37889411 -0.2736812  -0.49034201 -0.44177757]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.108, Inertia sementara: 82.595
# Titik data 50 (Fitur: [-0.39531699 -0.30834633 -0.49770819 -0.44177757]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.110, Inertia sementara: 82.706
# Titik data 51 (Fitur: [3.1629739  2.17887671 2.86126963 1.65565265]), Klaster: 1, Centroid: [2.3185641  1.57512571 2.60161181 2.82089167], Jarak kuadrat: 2.503, Inertia sementara: 85.209
# Titik data 52 (Fitur: [2.83451628 2.17887671 2.71394605 1.80764035]), Klaster: 1, Centroid: [2.3185641  1.57512571 2.60161181 2.82089167], Jarak kuadrat: 1.670, Inertia sementara: 86.879
# Titik data 53 (Fitur: [3.10823096 2.09221389 3.00859322 1.80764035]), Klaster: 1, Centroid: [2.3185641  1.57512571 2.60161181 2.82089167], Jarak kuadrat: 2.083, Inertia sementara: 88.962
# Titik data 54 (Fitur: [2.34182985 1.3989113  2.34563707 1.50366496]), Klaster: 1, Centroid: [2.3185641  1.57512571 2.60161181 2.82089167], Jarak kuadrat: 1.832, Inertia sementara: 90.794
# Titik data 55 (Fitur: [2.88925922 1.83222542 2.78760784 1.80764035]), Klaster: 1, Centroid: [2.3185641  1.57512571 2.60161181 2.82089167], Jarak kuadrat: 1.453, Inertia sementara: 92.247
# Titik data 56 (Fitur: [-0.35699694 -0.35167774 -0.26935663 -0.27459111]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.003, Inertia sementara: 92.250
# Titik data 57 (Fitur: [-0.32415118 -0.30834633 -0.25462427 -0.2289948 ]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.001, Inertia sementara: 92.251
# Titik data 58 (Fitur: [-0.40079129 -0.38634287 -0.35775078 -0.32018742]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.026, Inertia sementara: 92.278
# Titik data 59 (Fitur: [-0.3077283  -0.34301146 -0.26199045 -0.27459111]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.004, Inertia sementara: 92.281
# Titik data 60 (Fitur: [-0.38436841 -0.36034402 -0.3135537  -0.25939234]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.008, Inertia sementara: 92.289
# Titik data 61 (Fitur: [-0.39531699 -0.421008   -0.34301842 -0.32018742]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.028, Inertia sementara: 92.317
# Titik data 62 (Fitur: [-0.34604835 -0.33434517 -0.29145517 -0.24419357]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.003, Inertia sementara: 92.320
# Titik data 63 (Fitur: [-0.34057406 -0.40367543 -0.30618753 -0.32018742]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.016, Inertia sementara: 92.336
# Titik data 64 (Fitur: [-0.33509976 -0.34301146 -0.25462427 -0.25939234]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.001, Inertia sementara: 92.337
# Titik data 65 (Fitur: [-0.36247123 -0.34301146 -0.33565224 -0.27459111]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.011, Inertia sementara: 92.348
# Titik data 66 (Fitur: [-0.302254   -0.32567889 -0.27672281 -0.25939234]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.004, Inertia sementara: 92.352
# Titik data 67 (Fitur: [-0.36247123 -0.33434517 -0.26935663 -0.24419357]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.001, Inertia sementara: 92.353
# Titik data 68 (Fitur: [-0.35152265 -0.36034402 -0.29882135 -0.32018742]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.011, Inertia sementara: 92.364
# Titik data 69 (Fitur: [-0.32962547 -0.40367543 -0.26935663 -0.24419357]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.007, Inertia sementara: 92.370
# Titik data 70 (Fitur: [-0.36247123 -0.37767659 -0.3135537  -0.30498865]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.012, Inertia sementara: 92.383
# Titik data 71 (Fitur: [-0.34604835 -0.31701261 -0.24725809 -0.19859726]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.002, Inertia sementara: 92.384
# Titik data 72 (Fitur: [-0.33509976 -0.35167774 -0.30618753 -0.27459111]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.006, Inertia sementara: 92.391
# Titik data 73 (Fitur: [-0.32415118 -0.37767659 -0.23989191 -0.24419357]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.003, Inertia sementara: 92.393
# Titik data 74 (Fitur: [-0.33509976 -0.35167774 -0.25462427 -0.28978988]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.003, Inertia sementara: 92.397
# Titik data 75 (Fitur: [-0.31867688 -0.34301146 -0.28408899 -0.27459111]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.004, Inertia sementara: 92.401
# Titik data 76 (Fitur: [-0.3077283  -0.33434517 -0.27672281 -0.25939234]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.003, Inertia sementara: 92.404
# Titik data 77 (Fitur: [-0.29677971 -0.35167774 -0.24725809 -0.25939234]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.003, Inertia sementara: 92.408
# Titik data 78 (Fitur: [-0.302254   -0.33434517 -0.23252573 -0.21379603]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.003, Inertia sementara: 92.411
# Titik data 79 (Fitur: [-0.34057406 -0.34301146 -0.26935663 -0.24419357]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.001, Inertia sementara: 92.412
# Titik data 80 (Fitur: [-0.35699694 -0.3690103  -0.34301842 -0.32018742]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.019, Inertia sementara: 92.431
# Titik data 81 (Fitur: [-0.36794553 -0.38634287 -0.32091988 -0.30498865]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.014, Inertia sementara: 92.445
# Titik data 82 (Fitur: [-0.36794553 -0.38634287 -0.32828606 -0.32018742]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.018, Inertia sementara: 92.463
# Titik data 83 (Fitur: [-0.35152265 -0.36034402 -0.3135537  -0.28978988]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.009, Inertia sementara: 92.472
# Titik data 84 (Fitur: [-0.34057406 -0.36034402 -0.22515955 -0.2289948 ]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.001, Inertia sementara: 92.473
# Titik data 85 (Fitur: [-0.37341982 -0.33434517 -0.26935663 -0.24419357]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.002, Inertia sementara: 92.475
# Titik data 86 (Fitur: [-0.34057406 -0.29968004 -0.26935663 -0.2289948 ]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.002, Inertia sementara: 92.477
# Titik data 87 (Fitur: [-0.302254   -0.32567889 -0.25462427 -0.24419357]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.002, Inertia sementara: 92.479
# Titik data 88 (Fitur: [-0.32415118 -0.39500915 -0.27672281 -0.27459111]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.007, Inertia sementara: 92.486
# Titik data 89 (Fitur: [-0.36247123 -0.33434517 -0.29882135 -0.27459111]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.005, Inertia sementara: 92.491
# Titik data 90 (Fitur: [-0.36794553 -0.37767659 -0.30618753 -0.27459111]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.008, Inertia sementara: 92.500
# Titik data 91 (Fitur: [-0.36794553 -0.3690103  -0.27672281 -0.28978988]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.006, Inertia sementara: 92.506
# Titik data 92 (Fitur: [-0.33509976 -0.33434517 -0.26199045 -0.25939234]), Klaster: 0, Centroid: [-0.34755702 -0.33079677 -0.23971791 -0.23892785], Jarak kuadrat: 0.001, Inertia sementara: 92.507
# ...
# Titik data 70 (Fitur: [-0.36247123 -0.37767659 -0.3135537  -0.30498865]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.009, Inertia sementara: 85.741
# Titik data 71 (Fitur: [-0.34604835 -0.31701261 -0.24725809 -0.19859726]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.005, Inertia sementara: 85.746
# Titik data 72 (Fitur: [-0.33509976 -0.35167774 -0.30618753 -0.27459111]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.005, Inertia sementara: 85.751
# Titik data 73 (Fitur: [-0.32415118 -0.37767659 -0.23989191 -0.24419357]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.003, Inertia sementara: 85.755
# Titik data 74 (Fitur: [-0.33509976 -0.35167774 -0.25462427 -0.28978988]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.001, Inertia sementara: 85.756
# Titik data 75 (Fitur: [-0.31867688 -0.34301146 -0.28408899 -0.27459111]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.003, Inertia sementara: 85.759
# Titik data 76 (Fitur: [-0.3077283  -0.33434517 -0.27672281 -0.25939234]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.003, Inertia sementara: 85.762
# Titik data 77 (Fitur: [-0.29677971 -0.35167774 -0.24725809 -0.25939234]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.003, Inertia sementara: 85.765
# Titik data 78 (Fitur: [-0.302254   -0.33434517 -0.23252573 -0.21379603]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.005, Inertia sementara: 85.770
# Titik data 79 (Fitur: [-0.34057406 -0.34301146 -0.26935663 -0.24419357]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.002, Inertia sementara: 85.772
# Titik data 80 (Fitur: [-0.35699694 -0.3690103  -0.34301842 -0.32018742]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.015, Inertia sementara: 85.787
# Titik data 81 (Fitur: [-0.36794553 -0.38634287 -0.32091988 -0.30498865]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.011, Inertia sementara: 85.798
# Titik data 82 (Fitur: [-0.36794553 -0.38634287 -0.32828606 -0.32018742]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.014, Inertia sementara: 85.812
# Titik data 83 (Fitur: [-0.35152265 -0.36034402 -0.3135537  -0.28978988]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.007, Inertia sementara: 85.819
# Titik data 84 (Fitur: [-0.34057406 -0.36034402 -0.22515955 -0.2289948 ]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.003, Inertia sementara: 85.821
# Titik data 85 (Fitur: [-0.37341982 -0.33434517 -0.26935663 -0.24419357]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.002, Inertia sementara: 85.823
# Titik data 86 (Fitur: [-0.34057406 -0.29968004 -0.26935663 -0.2289948 ]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.003, Inertia sementara: 85.827
# Titik data 87 (Fitur: [-0.302254   -0.32567889 -0.25462427 -0.24419357]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.003, Inertia sementara: 85.830
# Titik data 88 (Fitur: [-0.32415118 -0.39500915 -0.27672281 -0.27459111]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.006, Inertia sementara: 85.836
# Titik data 89 (Fitur: [-0.36247123 -0.33434517 -0.29882135 -0.27459111]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.004, Inertia sementara: 85.839
# Titik data 90 (Fitur: [-0.36794553 -0.37767659 -0.30618753 -0.27459111]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.007, Inertia sementara: 85.846
# Titik data 91 (Fitur: [-0.36794553 -0.3690103  -0.27672281 -0.28978988]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.004, Inertia sementara: 85.850
# Titik data 92 (Fitur: [-0.33509976 -0.33434517 -0.26199045 -0.25939234]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.001, Inertia sementara: 85.851
# Titik data 93 (Fitur: [-0.35152265 -0.3690103  -0.30618753 -0.28978988]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.006, Inertia sementara: 85.857
# Titik data 94 (Fitur: [-0.39531699 -0.39500915 -0.35775078 -0.32018742]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.023, Inertia sementara: 85.880
# Titik data 95 (Fitur: [-0.36247123 -0.36034402 -0.29145517 -0.27459111]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.004, Inertia sementara: 85.884
# Titik data 96 (Fitur: [-0.35699694 -0.33434517 -0.29145517 -0.28978988]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.003, Inertia sementara: 85.887
# Titik data 97 (Fitur: [-0.35699694 -0.34301146 -0.29145517 -0.27459111]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.003, Inertia sementara: 85.890
# Titik data 98 (Fitur: [-0.32962547 -0.34301146 -0.28408899 -0.27459111]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.002, Inertia sementara: 85.892
# Titik data 99 (Fitur: [-0.3898427  -0.37767659 -0.37984932 -0.30498865]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.025, Inertia sementara: 85.917
# Titik data 100 (Fitur: [-0.35699694 -0.35167774 -0.29882135 -0.27459111]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.004, Inertia sementara: 85.921
# Titik data 101 (Fitur: [2.77977334 2.26553954 3.81887296 3.32751733]), Klaster: 1, Centroid: [2.85093916 1.96221965 3.16328299 2.21800714], Jarak kuadrat: 1.758, Inertia sementara: 87.679
# Titik data 102 (Fitur: [2.50605866 1.74556259 3.15591681 2.41559114]), Klaster: 1, Centroid: [2.85093916 1.96221965 3.16328299 2.21800714], Jarak kuadrat: 0.205, Inertia sementara: 87.884
# Titik data 103 (Fitur: [3.21771684 2.00555106 3.74521117 2.71956654]), Klaster: 1, Centroid: [2.85093916 1.96221965 3.16328299 2.21800714], Jarak kuadrat: 0.727, Inertia sementara: 88.611
# Titik data 104 (Fitur: [2.77977334 1.91888824 3.52422578 2.26360344]), Klaster: 1, Centroid: [2.85093916 1.96221965 3.16328299 2.21800714], Jarak kuadrat: 0.139, Inertia sementara: 88.750
# Titik data 105 (Fitur: [2.88925922 2.00555106 3.67154937 2.87155424]), Klaster: 1, Centroid: [2.85093916 1.96221965 3.16328299 2.21800714], Jarak kuadrat: 0.689, Inertia sementara: 89.439
# Titik data 106 (Fitur: [-0.25298536 -0.33434517 -0.11466686 -0.15300095]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.038, Inertia sementara: 89.477
# Titik data 107 (Fitur: [-0.40079129 -0.37767659 -0.26935663 -0.21379603]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.009, Inertia sementara: 89.485
# Titik data 108 (Fitur: [-0.26940824 -0.34301146 -0.1367654  -0.19859726]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.022, Inertia sementara: 89.507
# Titik data 109 (Fitur: [-0.302254   -0.37767659 -0.1735963  -0.19859726]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.013, Inertia sementara: 89.521
# Titik data 110 (Fitur: [-0.27488253 -0.28234748 -0.15149776 -0.09220587]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.046, Inertia sementara: 89.567
# Titik data 111 (Fitur: [-0.31320259 -0.31701261 -0.22515955 -0.16819972]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.011, Inertia sementara: 89.578
# Titik data 112 (Fitur: [-0.31867688 -0.36034402 -0.21042719 -0.18339849]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.010, Inertia sementara: 89.588
# Titik data 113 (Fitur: [-0.29677971 -0.33434517 -0.19569483 -0.15300095]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.018, Inertia sementara: 89.605
# Titik data 114 (Fitur: [-0.35699694 -0.37767659 -0.23252573 -0.16819972]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.012, Inertia sementara: 89.618
# Titik data 115 (Fitur: [-0.35152265 -0.35167774 -0.22515955  5.91130819]), Klaster: 3, Centroid: [-0.32962547 -0.34301146 -0.19815023  4.999382  ], Jarak kuadrat: 0.833, Inertia sementara: 90.450
# Titik data 116 (Fitur: [-0.31867688 -0.31701261 -0.21042719 -0.12260341]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.023, Inertia sementara: 90.473
# Titik data 117 (Fitur: [-0.31320259 -0.33434517 -0.19569483 -0.19859726]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.008, Inertia sementara: 90.481
# Titik data 118 (Fitur: [-0.24751107 -0.26501491 -0.10730068 -0.13780218]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.049, Inertia sementara: 90.530
# Titik data 119 (Fitur: [-0.24751107 -0.3690103  -0.09256832 -0.12260341]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.054, Inertia sementara: 90.584
# Titik data 120 (Fitur: [-0.34057406 -0.40367543  3.08225502 -0.24419357]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 11.044, Inertia sementara: 101.629
# Titik data 121 (Fitur: [-0.29130541 -0.31701261 -0.18096247 -0.12260341]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.028, Inertia sementara: 101.657
# Titik data 122 (Fitur: [-0.36247123 -0.35167774 -0.23989191 -0.16819972]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.010, Inertia sementara: 101.667
# Titik data 123 (Fitur: [-0.24751107 -0.35167774 -0.10730068 -0.16819972]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.038, Inertia sementara: 101.705
# Titik data 124 (Fitur: [-0.32415118 -0.36034402 -0.23989191 -0.19859726]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.006, Inertia sementara: 101.711
# Titik data 125 (Fitur: [-0.302254   -0.30834633 -0.18096247 -0.15300095]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.019, Inertia sementara: 101.730
# Titik data 126 (Fitur: [-0.27488253 -0.31701261 -0.15886394  2.26360344]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 6.417, Inertia sementara: 108.148
# Titik data 127 (Fitur: [-0.32962547 -0.35167774 -0.24725809 -0.19859726]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.006, Inertia sementara: 108.153
# Titik data 128 (Fitur: [-0.33509976 -0.33434517 -0.23989191 -0.19859726]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.005, Inertia sementara: 108.158
# Titik data 129 (Fitur: [-0.31867688 -0.35167774 -0.18832865 -0.15300095]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.017, Inertia sementara: 108.175
# Titik data 130 (Fitur: [-0.27488253 -0.33434517  3.67154937 -0.2289948 ]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 15.308, Inertia sementara: 123.484
# Titik data 131 (Fitur: [-0.26393395 -0.35167774 -0.15149776 -0.18339849]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.022, Inertia sementara: 123.506
# Titik data 132 (Fitur: [-0.23656248 -0.26501491 -0.12939922 -0.16819972]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.039, Inertia sementara: 123.545
# Titik data 133 (Fitur: [-0.31867688 -0.35167774 -0.18832865 -0.13780218]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.021, Inertia sementara: 123.565
# Titik data 134 (Fitur: [-0.32415118 -0.35167774 -0.22515955 -0.24419357]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.002, Inertia sementara: 123.567
# Titik data 135 (Fitur: [-0.33509976 -0.3690103  -0.18832865  5.75932049]), Klaster: 3, Centroid: [-0.32962547 -0.34301146 -0.19815023  4.999382  ], Jarak kuadrat: 0.578, Inertia sementara: 124.145
# Titik data 136 (Fitur: [-0.24751107 -0.33434517 -0.15149776 -0.12260341]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.039, Inertia sementara: 124.184
# Titik data 137 (Fitur: [-0.32415118 -0.29968004 -0.18832865 -0.10740464]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.030, Inertia sementara: 124.214
# Titik data 138 (Fitur: [-0.31867688 -0.32567889 -0.19569483 -0.19859726]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.008, Inertia sementara: 124.222
# Titik data 139 (Fitur: [-0.34057406 -0.33434517 -0.24725809 -0.19859726]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.005, Inertia sementara: 124.227
# Titik data 140 (Fitur: [-0.29130541 -0.32567889  2.71394605 -0.15300095]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 8.743, Inertia sementara: 132.970
# Titik data 141 (Fitur: [-0.302254   -0.32567889 -0.18832865 -0.10740464]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.030, Inertia sementara: 133.000
# Titik data 142 (Fitur: [-0.29130541 -0.32567889 -0.22515955 -0.12260341]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.024, Inertia sementara: 133.024
# Titik data 143 (Fitur: [-0.35152265 -0.36034402 -0.22515955 -0.18339849]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.008, Inertia sementara: 133.033
# Titik data 144 (Fitur: [-0.29677971 -0.31701261 -0.16623012 -0.12260341]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.029, Inertia sementara: 133.062
# Titik data 145 (Fitur: [-0.302254   -0.30834633 -0.18096247  3.32751733]), Klaster: 3, Centroid: [-0.32962547 -0.34301146 -0.19815023  4.999382  ], Jarak kuadrat: 2.797, Inertia sementara: 135.859
# Titik data 146 (Fitur: [-0.302254   -0.33434517 -0.21779337 -0.12260341]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.024, Inertia sementara: 135.883
# Titik data 147 (Fitur: [-0.32415118 -0.37767659 -0.23252573 -0.18339849]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.010, Inertia sementara: 135.892
# Titik data 148 (Fitur: [-0.31320259 -0.33434517 -0.21779337 -0.16819972]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.012, Inertia sementara: 135.904
# Titik data 149 (Fitur: [-0.32962547 -0.29968004 -0.20306101 -0.12260341]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.024, Inertia sementara: 135.928
# Titik data 150 (Fitur: [-0.34604835 -0.33434517 -0.22515955 -0.19859726]), Klaster: 0, Centroid: [-0.34791656 -0.33097495 -0.24018422 -0.26723297], Jarak kuadrat: 0.005, Inertia sementara: 135.933
#
# Total Inertia Manual: 135.933
# Inertia dari sklearn: 135.933
# ==================================================

# %% [markdown]
# ## **Model Plotting Diagram Elbow Method**

# %%
# 1. Siapkan fitur (X) dan label (y)
feature_names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
X = df_merged[feature_names].values
y = df_merged['class'].astype('category').cat.codes.values  # label dikodekan ke angka

# 2. Standarisasi data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 3. Hitung inertia untuk berbagai nilai k
inertias = []
K_range = range(1, 11)

for k in K_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X_scaled)
    inertias.append(kmeans.inertia_)

# 4. Plot Elbow Diagram
plt.figure(figsize=(9, 6))
plt.plot(K_range, inertias, 'bo-', markersize=8, label='Inertia')
plt.title("Metode Elbow - Menentukan Jumlah Klaster Optimal")
plt.xlabel("Jumlah Klaster (k)")
plt.ylabel("Inertia")
plt.xticks(K_range)
plt.grid(True)

# Tambahkan label inertia di tiap titik
for i, inertia in enumerate(inertias):
    plt.text(K_range[i], inertias[i] + 1, f"{inertia:.2f}", ha='center', fontsize=9)

plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Menghitung Silhouette Score untuk Jumlah Cluster 2,3 dan 4**

# %%
# 1. Siapkan fitur (X) dan label (y)
feature_names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
X = df_merged[feature_names].values
y = df_merged['class'].astype('category').cat.codes.values  # label dikodekan ke angka

# 2. Standarisasi data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 3. Fungsi untuk melakukan K-Means dan menghitung Silhouette Score
def perform_kmeans_with_silhouette(X_scaled, k):
    kmeans = KMeans(n_clusters=k, random_state=42)
    labels = kmeans.fit_predict(X_scaled)

    # Menghitung Silhouette Score
    silhouette_avg = silhouette_score(X_scaled, labels)

    # Centroid dari masing-masing klaster
    centroids = kmeans.cluster_centers_

    # Output hasil untuk klaster k
    print(f"\n=== Hasil K-Means dengan {k} Klaster ===")
    print(f"Centroids:\n{centroids}")
    print(f"Silhouette Score untuk {k} klaster: {silhouette_avg:.3f}")

    return silhouette_avg

# 4. Melakukan clustering dan menghitung Silhouette Score untuk k=2, 3, dan 4
silhouette_scores = []
k_values = [2, 3, 4]

for k in k_values:
    score = perform_kmeans_with_silhouette(X_scaled, k)
    silhouette_scores.append(score)

# 5. Menentukan k dengan Silhouette Score terbaik
best_k = k_values[np.argmax(silhouette_scores)]
best_score = max(silhouette_scores)
print(f"\n>>> Jumlah cluster terbaik dengan dengan Silhouette Score mendekati 1 adalah k = {best_k} (dengan score = {best_score:.3f})")

# 6. Plot Silhouette Scores
plt.figure(figsize=(8, 5))
plt.plot(k_values, silhouette_scores, 'bo-', markersize=8)
plt.title("Silhouette Score untuk Jumlah Klaster yang Berbeda")
plt.xlabel("Jumlah Klaster (k)")
plt.ylabel("Silhouette Score")
plt.xticks(k_values)
plt.grid(True)
plt.show()
# Out:
# === Hasil K-Means dengan 2 Klaster ===
# Centroids:
# [[-0.20363851 -0.14015855 -0.22594879 -0.15842908]
#  [ 2.85093916  1.96221965  3.16328299  2.21800714]]
# Silhouette Score untuk 2 klaster: 0.796
#
# === Hasil K-Means dengan 3 Klaster ===
# Centroids:
# [[-0.34755702 -0.33079677 -0.23971791 -0.23892785]
#  [ 2.3185641   1.57512571  2.60161181  2.82089167]
#  [ 1.48336107  2.10088017 -0.07046978 -0.31880571]]
# Silhouette Score untuk 3 klaster: 0.799
#
# === Hasil K-Means dengan 4 Klaster ===
# Centroids:
# [[-0.34791656 -0.33097495 -0.24018422 -0.26723297]
#  [ 2.85093916  1.96221965  3.16328299  2.21800714]
#  [ 1.48336107  2.10088017 -0.07046978 -0.31880571]
#  [-0.32962547 -0.34301146 -0.19815023  4.999382  ]]
# Silhouette Score untuk 4 klaster: 0.825
#
# >>> Jumlah cluster terbaik dengan dengan Silhouette Score mendekati 1 adalah k = 4 (dengan score = 0.825)
